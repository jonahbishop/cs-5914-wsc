# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import axes
import numpy as np

# %%
rf_train = [0.6413218361322396, 0.6405907444081628, 0.9658463635614654, 0.5483494634387169]
rf_test = [0.640840134090224, 0.6403637418980361, 0.9652875400292819, 0.5478778534191893]
rf_merge_train = [0.655744912819615,0.652846083049104,0.9594902544908274,0.5776992566836087]
rf_merge_test = [0.654988112485605,0.6536462148576625, 0.9575211284282817,0.5765299402049197]
rf_hp = {'Max Depth': 10,'Max Bins': 20,'Num Trees': 5}

# %%
gbt = [0.6809400843330173,0.6964871700845299,0.8641483460396531,0.6585445709379646]
gbt_merge = [0.6892018648538207,0.7044717226656433,0.8693885706673771,0.6673253020229196]

# %%
lsvc = [0.623040129005546,0.6365195841002292,0.9198656066076751,0.54795829982099]
lsvc_merge = [0.6375654742003789,0.6373018355024177,0.9802702662699998,0.5257833347294636]

# %%
lr =[0.6465495011567642,0.6612467421714217, 0.8864772482019634,0.6031957270414608]
lr_merge = [0.6595527322708867,0.6755706543351551,0.8800526915619495,0.6236928196132752]

# %%
airline = [0.6791398401533837,0.5478778534191893,0.5480691280475394,0.6031453768366104]
merge = [0.6673253020229196,0.5765299402049197,0.5257833347294636,0.6236928196132752]

# %%
df = pd.DataFrame(index=['airplane', 'merged'], columns=['Accuracy', 'Precision', 'Recall', 'F1'], data=[gbt, gbt_merge])
df
# Out:
#           Accuracy  Precision    Recall        F1
# airplane  0.680940   0.696487  0.864148  0.658545
# merged    0.689202   0.704472  0.869389  0.667325

# %%
ax = df.T.plot(kind='bar', rot=1, colormap='Dark2', alpha=0.8, title="Gradient Boosted Tree Metrics", ylabel="Probability")
ax.set_ybound([0, 1])
